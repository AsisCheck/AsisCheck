# %%
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import numpy as np
clase= pd.read_csv("Clase2020.csv")
clase
# Out:
#     Carrera  FaltasAcumuladas  Estudio
# 0       AGN                10      6.0
# 1       IAD                 6      5.0
# 2       AGI                 7     10.0
# 3       AGI                 0      2.0
# 4       AGI                 8     10.0
# ..      ...               ...      ...
# 382     CPA                 0      6.0
# 383     IAD                 5      4.0
# 384     AGI                 2      9.0
# 385     CPA                 6     20.0
# 386     AGI                 5     12.0
#
# [387 rows x 3 columns]

# %%
cpa=clase[clase.Carrera=="CPA"]

# %%
cpa
# Out:
#     Carrera  FaltasAcumuladas  Estudio
# 8       CPA                 6      4.0
# 9       CPA                 3     10.0
# 10      CPA                 0      8.0
# 11      CPA                 4     10.0
# 22      CPA                 4     15.0
# ..      ...               ...      ...
# 370     CPA                 0      6.0
# 376     CPA                 0     10.0
# 377     CPA                 2     14.0
# 382     CPA                 0      6.0
# 385     CPA                 6     20.0
#
# [189 rows x 3 columns]

# %%
agi=clase[clase.Carrera=="AGI"]

# %%
agi
# Out:
#     Carrera  FaltasAcumuladas  Estudio
# 2       AGI                 7     10.0
# 3       AGI                 0      2.0
# 4       AGI                 8     10.0
# 6       AGI                 0      4.0
# 14      AGI                 0      3.0
# ..      ...               ...      ...
# 375     AGI                 0     12.0
# 380     AGI                 2      4.0
# 381     AGI                 3     12.0
# 384     AGI                 2      9.0
# 386     AGI                 5     12.0
#
# [103 rows x 3 columns]

# %%
agn=clase[clase.Carrera=="AGN"]

# %%
agn
# Out:
#     Carrera  FaltasAcumuladas  Estudio
# 0       AGN                10      6.0
# 5       AGN                11      6.0
# 15      AGN                 6     11.0
# 26      AGN                 0      5.0
# 27      AGN                 3     21.0
# 35      AGN                 0     12.0
# 51      AGN                 0      5.0
# 62      AGN                 2     10.0
# 71      AGN                 2     10.0
# 90      AGN                 2     15.0
# 101     AGN                10      7.0
# 114     AGN                 1     20.0
# 122     AGN                10      6.0
# 139     AGN                 0     14.0
# 151     AGN                14     18.0
# 152     AGN                 9     12.0
# 159     AGN                10     10.0
# 165     AGN                 5      4.0
# 168     AGN                 0      8.0
# 172     AGN                 2      5.0
# 185     AGN                10     15.0
# 189     AGN                 9     12.0
# 199     AGN                 7      8.0
# ...

# %%
iad=clase[clase.Carrera=="IAD"]

# %%
iad
# Out:
#     Carrera  FaltasAcumuladas  Estudio
# 1       IAD                 6      5.0
# 7       IAD                 6     15.0
# 12      IAD                 1     20.0
# 13      IAD                 0     34.0
# 16      IAD                 2     10.0
# 17      IAD                 0      5.0
# 18      IAD                 1     20.0
# 21      IAD                 0     10.0
# 37      IAD                 4     30.0
# 43      IAD                 0      2.0
# 56      IAD                 8     18.0
# 60      IAD                 0      6.0
# 68      IAD                 1      5.0
# 76      IAD                 0     12.0
# 87      IAD                 5     10.0
# 88      IAD                 5      7.0
# 92      IAD                 1     15.0
# 93      IAD                 3     20.0
# 107     IAD                 3     10.0
# 109     IAD                 2     15.0
# 128     IAD                 5     20.0
# 137     IAD                 2      3.0
# 154     IAD                 5     11.0
# ...

# %%
fig, ax = plt.subplots()
# Dibujar puntos
ax.scatter(x = [cpa.FaltasAcumuladas], y = [cpa.Estudio])        
plt.show()

# %%
N = 189
x = cpa.FaltasAcumuladas
y = cpa.Estudio
colors = np.random.rand(N)
area = (10 * np.random.rand(N))**2  # 0 to 15 point radii
plt.scatter(x, y, s=area, c=colors, alpha=0.7)
plt.show()

# %%
N = 103
x = agi.FaltasAcumuladas
y = agi.Estudio
colors = np.random.rand(N)
area = (10 * np.random.rand(N))**2  # 0 to 15 point radii
plt.scatter(x, y, s=area, c=colors, alpha=0.8)
plt.show()

# %%
N = 54
x = agn.FaltasAcumuladas
y = agn.Estudio
colors = np.random.rand(N)
area = (10 * np.random.rand(N))**2  # 0 to 15 point radii
plt.scatter(x, y, s=area, c=colors, alpha=0.7)
plt.show()

# %%
N = 41
x = iad.FaltasAcumuladas
y = iad.Estudio
colors = np.random.rand(N)
area = (10 * np.random.rand(N))**2  # 0 to 15 point radii
plt.scatter(x, y, s=area, c=colors, alpha=0.7)
plt.show()
